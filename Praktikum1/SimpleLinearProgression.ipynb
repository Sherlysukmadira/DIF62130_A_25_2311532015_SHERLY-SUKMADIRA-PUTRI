# %% [markdown]
# <a href="https://colab.research.google.com/github/Sherlysukmadira/DIF62130_A_25_2311532015_SHERLY-SUKMADIRA-PUTRI/blob/main/Praktikum1/SimpleLinearProgression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Simple Linear Regression (varibael bebasnya cuma 1)

# %%
import pandas as pd

data = {'luas' : [6, 8, 10, 14, 18],
        'harga' : [7, 9, 13, 15.5, 18]}
df = pd.DataFrame(data)
df
# Out:
#    luas  harga
# 0     6    7.0
# 1     8    9.0
# 2    10   13.0
# 3    14   15.5
# 4    18   18.0

# %%
import matplotlib.pyplot as plt

df.plot(kind='scatter', x= 'luas', y='harga')
plt.title('Perbandingan Luas Tanah dengan Harga Jual')
plt.xlabel('Luas Tanah (m persegi)')
plt.ylabel('Harga Tanah (dollar)')
plt.xlim(0, 25)
plt.ylim(0, 25)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np

X=np.array(df['luas'])
y=np.array(df['harga'])

print(f'X: {X}')
print(f'y: {y}')
# Out:
# X: [ 6  8 10 14 18]
# y: [ 7.   9.  13.  15.5 18. ]

# %%
x= X.reshape(-1, 1)

print(f'x shape: {x.shape}')
print(f'x : {x}')
# Out:
# x shape: (5, 1)
# x : [[ 6]
#  [ 8]
#  [10]
#  [14]
#  [18]]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
X_vis = np.array([0,25]).reshape(-1,1)
y_vis = model.predict(X_vis)

# %%
plt.scatter(X, y)
plt.plot(X_vis, y_vis, c='red')

plt.title('Perbandingan Luas Tanah dengan Harga Tanah')
plt.xlabel('Luas Tanah (m persegi)')
plt.ylabel('Harga Tanah (dollar)')
#plt.Xlim(0, 25)
#plt.ylim(0, 25)
plt.grid(True)
plt.show()

# %%
print(f)

# %%
luas_tanah = np.array([12,15,21]).reshape(-1,1)
print(luas_tanah.shape)
luas_tanah
# Out:
# (3, 1)
# array([[12],
#        [15],
#        [21]])

# %%
harga_prediksi = model.predict(luas_tanah)
harga_prediksi
# Out:
# array([13.23275862, 15.98060345, 21.4762931 ])

# %%
for luas, hrg in zip(luas_tanah, harga_prediksi) :
  print(f'Luas Tanah{luas}: harga prediksi {hrg}')
# Out:
# Luas Tanah[12]: harga prediksi 13.232758620689655
# Luas Tanah[15]: harga prediksi 15.980603448275861
# Luas Tanah[21]: harga prediksi 21.476293103448274

# %% [markdown]
# Training & Testing

# %%
X_train = np.array([6, 8, 10, 14, 18]).reshape(-1,1)
y_train = np.array([7, 9, 13, 17.5, 18])

X_test = np.array([8, 9, 11, 16, 12]).reshape(-1,1)
y_test = np.array([11, 8.5, 15, 18, 11])

# %% [markdown]
# Training Simple Linear Regression

# %%
model=LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Evaluasi Linear regression

# %%
from sklearn.metrics import r2_score

y_pred = model.predict(X_test)
r_squared = r2_score(y_test, y_pred)
print(f'R-squared: {r_squared}')
# Out:
# R-squared: 0.6620052929422553

# %%
y_pred
# Out:
# array([ 9.77586207, 10.75215517, 12.70474138, 17.5862069 , 13.68103448])

# %%
y_test
# Out:
# array([11. ,  8.5, 15. , 18. , 11. ])
